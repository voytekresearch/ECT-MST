# %% [markdown]
# # This notebook is analzying the spectral parameters from the frontal EEG channels pre and post MST.
#
# We are only including frontal because we are basing our analyses off of Smith, 2022, in which their dataset only uses fronto-central channels. Additionally, the treatment is targeted to frontal/central areas.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import scipy
from statsmodels.formula.api import ols
from scipy.stats import ttest_rel
from pingouin import ttest, normality, wilcoxon

from plotting_functions import plot_feature_prepost
from matplotlib import rcParams
rcParams['font.family'] = 'Helvetica'
# Out:
# /Users/quirine/opt/anaconda3/envs/ECT_Hadas/lib/python3.8/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.0, the latest is 0.5.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
# %matplotlib inline

# %% [markdown]
# ### Functions

# %%
def perm_test(df, feature='', nreps=10000, seed=256, plot_hist=True, run_ttest=True):
    '''permutation test from https://www.uvm.edu/\~statdhtx/StatPages/\
    ResamplingWithR/RandomMatchedSample/RandomMatchedSampleR.html
    '''
    
    means_pre = df[df['pre_post']=='pre'][feature].values
    means_post = df[df['pre_post']=='post'][feature].values
    
    diff_obt = np.nanmedian(means_post) - np.nanmedian(means_pre)
    difference = means_post-means_pre
    
    np.random.seed(seed)
    resamp_mean_diff = np.zeros(nreps)

    for i in range(0, nreps):
        signs = np.random.choice([1, -1], len(difference), replace=True)
        resamp = difference * signs
        resamp_mean_diff[i] = np.nanmedian(resamp)

    diff_obt = abs(diff_obt)
    highprob = len(resamp_mean_diff[resamp_mean_diff >= diff_obt])/nreps
    lowprob = len(resamp_mean_diff[resamp_mean_diff <= -diff_obt])/nreps
    prob2tailed = lowprob + highprob

    print("The probability from the sampling statistics is = ",prob2tailed,'\n')

    if plot_hist:
        plt.hist(resamp_mean_diff, bins=30);
        plt.title(feature)
        plt.xlabel('Median Difference')
        plt.axvline(x=diff_obt, c='r')
        plt.axvline(x=-diff_obt, c='r')

    # compare to student's t-test
    if run_ttest:
        print(ttest(means_pre, means_post, paired=True))

# %%
FRONTAL_ONLY = True

# %%
# load dataframe
exp_df = pd.read_csv('../saved_files/mst_files/mst_all_features.csv', index_col = 0)

# Exclude channels from ppn's with bad fits
exp_df_included = exp_df[exp_df['exclude']==False]

# %%
frontal_channels = ['FP1', 'FPZ', 'FP2', 'AF3', 'AF4', 'F7', 'F5', 'F3', 'F1', 'FZ',
                    'F2', 'F4', 'F6', 'F8', 'FT7', 'FC5', 'FC3', 'FC1', 'FCZ', 'FC2',
                    'FC4', 'FC6', 'FT8', 'C5', 'C3', 'C1', 'CZ', 'C2', 'C4', 'C6']

if FRONTAL_ONLY:
    exp_df_included = exp_df_included[exp_df_included['channel'].isin(frontal_channels)]

# %% [markdown]
# ## Load SpecParam Fits

# %%
fits_pre = np.load('../saved_files/mst_files/mst_fits_pre.npy')
fits_post = np.load('../saved_files/mst_files/mst_fits_post.npy')
freq_axis = np.load('../saved_files/mst_files/mst_freq_axis.npy')

# %% [markdown]
# **Correct for excluded fits**

# %%
# get boolean area with True to exclude channels from patients
to_exclude_pre = exp_df['exclude'][exp_df['pre_post']=='pre'].values
to_exclude_post = exp_df['exclude'][exp_df['pre_post']=='post'].values

# reshape fits array from [23, 60,99] --> [1390, 99]
fits_pre_flat = fits_pre.reshape(len(to_exclude_pre), fits_pre.shape[2])
fits_post_flat = fits_post.reshape(len(to_exclude_pre), fits_pre.shape[2])

# replace to excluded ones with nans
fits_pre_flat[to_exclude_pre] = np.nan
fits_post_flat[to_exclude_post] = np.nan

# reshape back to original array from  [1390, 99] --> [23, 60,99]
fits_pre_included = fits_pre_flat.reshape(fits_pre.shape[0], fits_pre.shape[1], fits_pre.shape[2])
fits_post_included = fits_post_flat.reshape(fits_pre.shape[0], fits_pre.shape[1], fits_pre.shape[2])

# %% [markdown]
# ## Load PSD's

# %%
psd_pre = np.load('../saved_files/mst_files/pre_mst_psd.npy')
psd_post = np.load('../saved_files/mst_files/post_mst_psd.npy')

# %% [markdown]
# **Correct for excluded PSD's**

# %%
# reshape psd array from [23, 60,99] --> [1390, 99]
psd_pre_flat = psd_pre.reshape(len(to_exclude_pre), psd_pre.shape[2])
psd_post_flat = psd_post.reshape(len(to_exclude_pre), psd_pre.shape[2])

# replace to excluded ones with nans
psd_pre_flat[to_exclude_pre] = np.nan
psd_post_flat[to_exclude_post] = np.nan

# reshape back to original array from  [1390, 99] --> [23, 60,99]
psd_pre_included = psd_pre_flat.reshape(psd_pre.shape[0], psd_pre.shape[1], psd_pre.shape[2])
psd_post_included = psd_post_flat.reshape(psd_pre.shape[0], psd_pre.shape[1], psd_pre.shape[2])

# %% [markdown]
# ### Replace NaN's with 0's for oscillatory amplitude (aperiodic adjusted)
#
# There are so few delta oscillations, that we cannot run statistics (later on) using delta_amp. Therefore, we want to put a value instead of a NaN, and say that no oscillation = 0 mV.
#
# We may not end up using this no nan dataframe, and simply use permutation testing instead, but keeping this here just in case.

# %%
df_include_nonan = exp_df_included.copy()
df_include_nonan['delta_amp'] = df_include_nonan['delta_amp'].fillna(0)
df_include_nonan['theta_amp'] = df_include_nonan['theta_amp'].fillna(0)
df_include_nonan['alpha_amp'] = df_include_nonan['alpha_amp'].fillna(0)
df_include_nonan
# Out:
#       patient pre_post channel  delta_cf  delta_bw  delta_amp   delta_bp  \
# 0           9      pre     FP1       NaN       NaN        0.0 -11.280826
# 1           9      pre     FPZ       NaN       NaN        0.0 -11.309185
# 2           9      pre     FP2       NaN       NaN        0.0 -11.282578
# 3           9      pre     AF3       NaN       NaN        0.0 -11.233921
# 4           9      pre     AF4       NaN       NaN        0.0 -11.277614
# ...       ...      ...     ...       ...       ...        ...        ...
# 2726      191     post      C1       NaN       NaN        0.0 -12.112392
# 2727      191     post      CZ       NaN       NaN        0.0 -12.133087
# 2728      191     post      C2       NaN       NaN        0.0 -12.149901
# 2729      191     post      C4       NaN       NaN        0.0 -12.018729
# 2730      191     post      C6       NaN       NaN        0.0 -12.195663
#
#       theta_cf  theta_bw  theta_amp   theta_bp   alpha_cf  alpha_bw  \
# 0     5.997988  2.501555   0.667675 -11.313390   9.406764  2.569185
# 1     6.086847  2.554596   0.675706 -11.326472   9.449168  2.497624
# 2          NaN       NaN   0.000000 -11.397794   8.785747  5.107161
# 3          NaN       NaN   0.000000 -11.164987  10.155171  8.000000
# 4          NaN       NaN   0.000000 -11.283093  10.436366  8.000000
# ...        ...       ...        ...        ...        ...       ...
# 2726       NaN       NaN   0.000000 -12.313474  10.213649  4.252081
# 2727       NaN       NaN   0.000000 -12.328502   9.677589  3.754100
# 2728       NaN       NaN   0.000000 -12.313282   9.554998  3.752559
# 2729       NaN       NaN   0.000000 -12.262644   9.535750  3.739089
# 2730       NaN       NaN   0.000000 -12.234628   9.751732  4.675295
#
#       alpha_amp   alpha_bp     offset  exponent     error  r_squared  exclude
# 0      1.072654 -11.309979 -10.794617  1.474183  0.060640   0.986008    False
# 1      1.093702 -11.304463 -10.830635  1.446444  0.060675   0.985659    False
# 2      0.969494 -11.330043 -10.789054  1.503540  0.064948   0.983402    False
# 3      0.969552 -11.276905 -10.821901  1.394998  0.126346   0.952315    False
# 4      0.951637 -11.309732 -10.837673  1.422327  0.119482   0.958271    False
# ...         ...        ...        ...       ...       ...        ...      ...
# 2726   1.379008 -11.653503 -11.614495  1.294492  0.067299   0.984237    False
# 2727   1.437472 -11.682997 -11.637250  1.303703  0.086093   0.976572    False
# 2728   1.439360 -11.661415 -11.689465  1.222341  0.083656   0.976119    False
# 2729   1.346651 -11.671061 -11.618427  1.212657  0.067274   0.982381    False
# 2730   1.226480 -11.788274 -11.773520  1.119242  0.062010   0.981973    False
#
# [1336 rows x 20 columns]

# %% [markdown]
# ## Averaging Over All (*Frontal*) Electrodes Per Subject

# %% [markdown]
# **Average over with amplitudes as 0 (i.e. exp_df_mean_nonan)**

# %%
# Take features of interest + average over all electrodes per patient
features = ['exponent', 'offset', 'delta_amp', 'delta_bp', 'theta_amp', 'theta_bp', 'theta_cf', 'delta_cf',
            'alpha_amp', 'alpha_bp', 'alpha_bw', 'alpha_cf']
exp_df_mean_nonan = pd.DataFrame(df_include_nonan.groupby(['patient', 'pre_post'], as_index=False)[features].mean())

# %% [markdown]
# **Average over with NaNs (i.e. exp_df_mean)**

# %%
# Take features of interest + average over all electrodes per patient
features = ['exponent', 'offset', 'delta_amp', 'delta_bp', 'theta_amp', 'theta_bp', 'theta_cf', 'delta_cf',
            'alpha_amp', 'alpha_bp', 'alpha_bw', 'alpha_cf']
exp_df_mean = pd.DataFrame(exp_df_included.groupby(['patient', 'pre_post'], as_index=False)[features].mean())

# %%
SAVE_FIG = False
fig_path = '../figures/'

# %matplotlib qt

features = ['exponent', 'offset', 'delta_amp', 'delta_bp', 'delta_cf', 'theta_amp', 'theta_bp', 'theta_cf',
            'alpha_cf', 'alpha_amp', 'alpha_bp']

labels = ['aperiodic exponent ($\mu$V$^2$/Hz)', 'aperiodic offset ($\mu$V$^2$)',
          'delta oscillation power ($\mu$V$^2$)', 'delta band power ($\mu$V$^2$/Hz)', 'delta center frequency (Hz)',
          'theta oscillation power ($\mu$V$^2$)', 'theta band power ($\mu$V$^2$/Hz)', 'theta center frequency (Hz)',
          'alpha center frequency (Hz)', 'alpha oscillation Power ($\mu$V$^2$)', 'alpha band power ($\mu$V$^2$/Hz)' ]

for feature, label in zip(features, labels):
    plot_feature_prepost(exp_df_mean, feature=feature)
    plt.ylabel(label)
    sns.despine()
    plt.tight_layout()
    plt.show()
    
    if SAVE_FIG:
        plt.savefig(fig_path+feature+'.pdf', format='pdf')

# %% [markdown]
# ### Figure-Specific Axes

# %%
plot_feature_prepost(exp_df_mean, feature='exponent')
plt.ylabel('aperiodic exponent ($\mu$V$^2$/Hz)')
plt.ylim(0.3, 2.4)
sns.despine()
plt.tight_layout()
plt.show()

# %%
plot_feature_prepost(exp_df_mean, feature='delta_bp')
plt.ylabel('delta band power ($\mu$V$^2$/Hz)')
plt.ylim(-12.7, -9.9)
sns.despine()
plt.tight_layout()
plt.show()

# %%
plot_feature_prepost(exp_df_mean, feature='delta_amp')
plt.ylabel('delta oscillation power ($\mu$V$^2$)')
plt.ylim(0, 1.75)
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot Spectra

# %%
fits_pre_mean = np.nanmean(fits_pre_included, axis=1)
fits_post_mean = np.nanmean(fits_post_included, axis=1)

fits_pre_grand_mean = np.nanmean(fits_pre_included, axis=(0,1))
fits_post_grand_mean = np.nanmean(fits_post_included, axis=(0,1))

# %%
sns.set_context('poster')
plt.figure(figsize=[15,10])

# plot patient pre
for patient in range(0, fits_pre_mean.shape[0]):
    plt.plot(freq_axis[2:61], fits_pre_mean[patient], color='royalblue', alpha = 0.3, linewidth = 1)

# plot patient post
for patient in range(0, fits_post_mean.shape[0]):
    plt.plot(freq_axis[2:61], fits_post_mean[patient], color='salmon', alpha = 0.3, linewidth = 1)

# plot average pre
plt.plot(freq_axis[2:61], fits_pre_grand_mean, color='royalblue', linewidth = 4, label='pre')

# plot average post
plt.plot(freq_axis[2:61], fits_post_grand_mean, color='salmon', linewidth = 4, label='post')


plt.xscale('log')
plt.rc('xtick', labelsize=18)
plt.rc('ytick', labelsize=18)
plt.ylabel("power ($\mu$V$^2$)", fontsize = 25)
plt.xlabel("frequency (Hz)", fontsize = 25)
plt.legend(prop = {'size': 30})


sns.despine()

plt.show()
plt.savefig(fig_path+'spectra_fits.pdf', format='pdf')

# %% [markdown]
# ## Plot SpecParam Fits

# %%
psd_pre_mean = np.nanmean(psd_pre_included, axis=1)
psd_post_mean = np.nanmean(psd_post_included, axis=1)

psd_pre_grand_mean = np.nanmean(psd_pre_included, axis=(0,1))
psd_post_grand_mean = np.nanmean(psd_post_included, axis=(0,1))

# %%
# plot patient pre

sns.set_context('poster')
plt.figure(figsize=[15,10])

for patient in range(0, psd_pre_mean.shape[0]):
    plt.plot(freq_axis[2:61], np.log10(psd_pre_mean[patient,2:61]), color='royalblue', alpha = 0.3, linewidth = 1)

# plot patient post
for patient in range(0, psd_post_mean.shape[0]):
    plt.plot(freq_axis[2:61], np.log10(psd_post_mean[patient,2:61]), color='salmon', alpha = 0.3, linewidth = 1)

# plot average pre
plt.plot(freq_axis[2:61], np.log10(psd_pre_grand_mean[2:61]), color='royalblue', linewidth = 4, label='pre')

# plot average post
plt.plot(freq_axis[2:61], np.log10(psd_post_grand_mean[2:61]), color='salmon', linewidth = 4, label='post')


plt.xscale('log')
plt.rc('xtick', labelsize=18)
plt.rc('ytick', labelsize=18)
plt.ylabel("power ($\mu$V$^2$)", fontsize = 25)
plt.xlabel("frequency (Hz)", fontsize = 25)
plt.legend(prop = {'size': 30})


sns.despine()

plt.show()

# %% [markdown]
# # Statistics

# %% [markdown]
# ### Exponent: Pre/Post

# %% [markdown]
# **Normality**

# %%
means_pre = exp_df_mean[exp_df_mean['pre_post']=='pre']['exponent'].values
means_post = exp_df_mean[exp_df_mean['pre_post']=='post']['exponent'].values

# normality test
print(normality(means_pre, method='shapiro'))
print(normality(means_post, method='shapiro'))
# Out:
#           W      pval  normal
# 0  0.940686  0.185913    True
#           W      pval  normal
# 0  0.941776  0.196178    True

# %%
print('pre: ' + str(means_pre.mean()))
print('post: ' + str(means_post.mean()))
# Out:
# pre: 0.9574658537873503
# post: 1.149622249292333

# %% [markdown]
# **Distribution of means pre vs. post**

# %%
plt.hist(means_pre, color = 'royalblue', alpha = 0.5, label = 'pre')
plt.hist(means_post, color = 'salmon', alpha = 0.5, label = 'post')
plt.legend()
plt.title('Exponent')
plt.show()

# %% [markdown]
# **Wilcoxon Test**

# %%
print(wilcoxon(means_pre, means_post))
# Out:
#           W-val alternative     p-val       RBC      CLES
# Wilcoxon   50.0   two-sided  0.006033 -0.637681  0.286389

# %% [markdown]
# **Permutation Test & T-Test**

# %%
perm_test(exp_df_mean, feature='exponent')
# Out:
# The probability from the sampling statistics is =  0.0039
#
#               T  dof alternative     p-val           CI95%   cohen-d    BF10  \
# T-test -3.18452   22   two-sided  0.004285  [-0.32, -0.07]  0.815402  10.057
#
#            power
# T-test  0.962035

# %% [markdown]
# ### Offset: Pre/Post

# %%
means_pre = exp_df_mean[exp_df_mean['pre_post']=='pre']['offset'].values
means_post = exp_df_mean[exp_df_mean['pre_post']=='post']['offset'].values

# normality test
print(normality(means_pre, method='shapiro'))
print(normality(means_post, method='shapiro'))
# Out:
#           W      pval  normal
# 0  0.969273  0.671606    True
#          W      pval  normal
# 0  0.96344  0.536211    True

# %% [markdown]
# **Distribution of means pre vs. post**

# %%
plt.hist(means_pre, color = 'royalblue', alpha = 0.5, label = 'pre')
plt.hist(means_post, color = 'salmon', alpha = 0.5, label = 'post')
plt.legend()
plt.title('Offset')
plt.show()

# %%
print(wilcoxon(means_pre, means_post))
# Out:
#           W-val alternative     p-val       RBC      CLES
# Wilcoxon   67.0   two-sided  0.030087 -0.514493  0.339319

# %% [markdown]
# **Permutation Test & T-Test**

# %%
perm_test(exp_df_mean, feature='offset')
# Out:
# The probability from the sampling statistics is =  0.07980000000000001
#
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -2.639654   22   two-sided  0.014968  [-0.5, -0.06]  0.617812  3.507
#
#            power
# T-test  0.808265

# %% [markdown]
# ### Delta Oscillatory Power: Pre/Post

# %% [markdown]
# **Normality**

# %%
means_pre = exp_df_mean[exp_df_mean['pre_post']=='pre']['delta_amp'].values # .dropna(how="any")
means_post = exp_df_mean[exp_df_mean['pre_post']=='post']['delta_amp'].values

# normality test
print(normality(means_pre, method='shapiro'))
print(normality(means_post, method='shapiro'))
# Out:
#           W      pval  normal
# 0  0.783664  0.076067    True
#           W      pval  normal
# 0  0.803275  0.031029   False

# %% [markdown]
# **Distribution of means pre vs. post**
#
# This one is tricky to do stats for because the pre has so few channels that even detect a delta oscillation. When we try to keep the 0's instead of NaNs, the Wilcoxon test fails due to 'ties'. Therefore, we are keeping the NaNs, and will just report the permutation test for statistics.

# %%
plt.hist(means_pre, color = 'royalblue', alpha = 0.5, label = 'pre')
plt.hist(means_post, color = 'salmon', alpha = 0.5, label = 'post')
plt.legend()
plt.title('Delta amplitude')
plt.show()

# %%
print(wilcoxon(means_pre, means_post))
# Out:
#           W-val alternative  p-val  RBC  CLES
# Wilcoxon    0.0   two-sided    0.5 -1.0   0.0

# %% [markdown]
# **Permutation Test & T-Test**

# %%
perm_test(exp_df_mean, feature='delta_amp')
# Out:
# The probability from the sampling statistics is =  0.0
#
#                T  dof alternative     p-val          CI95%   cohen-d  BF10  \
# T-test -1.787104    1   two-sided  0.324776  [-1.52, 1.14]  1.397807  0.98
#
#            power
# T-test  0.124389

# %% [markdown]
# ### Delta Band Power: Pre/Post

# %% [markdown]
# **Normality**

# %%
means_pre = exp_df_mean[exp_df_mean['pre_post']=='pre']['delta_bp'].values
means_post = exp_df_mean[exp_df_mean['pre_post']=='post']['delta_bp'].values

# normality test
print(normality(means_pre, method='shapiro'))
print(normality(means_post, method='shapiro'))
# Out:
#           W     pval  normal
# 0  0.965228  0.57647    True
#           W      pval  normal
# 0  0.980234  0.910117    True

# %%
print('pre: ' + str(means_pre.mean()))
print('post: ' + str(means_post.mean()))
# Out:
# pre: -11.928236858878602
# post: -11.685777782293206

# %% [markdown]
# **Distribution of means pre vs. post**

# %%
plt.hist(means_pre, color = 'royalblue', alpha = 0.5, label = 'pre')
plt.hist(means_post, color = 'salmon', alpha = 0.5, label = 'post')
plt.legend()
plt.title('Delta band power')
plt.show()

# %% [markdown]
# **Wilcoxon Test**

# %%
print(wilcoxon(means_pre, means_post))
# Out:
#           W-val alternative     p-val       RBC      CLES
# Wilcoxon   64.0   two-sided  0.023325 -0.536232  0.333648

# %% [markdown]
# **Permutation Test & T-Test**

# %%
perm_test(exp_df_mean, feature='delta_bp')
# Out:
# The probability from the sampling statistics is =  0.036699999999999997
#
#                T  dof alternative     p-val           CI95%   cohen-d   BF10  \
# T-test -2.608826   22   two-sided  0.016029  [-0.44, -0.05]  0.613442  3.314
#
#            power
# T-test  0.802762

# %% [markdown]
# ### Delta Center Frequency: Pre/Post

# %% [markdown]
# **Normality**

# %%
means_pre = exp_df_mean[exp_df_mean['pre_post']=='pre']['delta_cf'].values
means_post = exp_df_mean[exp_df_mean['pre_post']=='post']['delta_cf'].values

# normality test
print(normality(means_pre, method='shapiro'))
print(normality(means_post, method='shapiro'))
# Out:
#           W      pval  normal
# 0  0.934091  0.504135    True
#           W      pval  normal
# 0  0.765999  0.012254   False

# %% [markdown]
# **Distribution of means pre vs. post**

# %%
plt.hist(means_pre, color = 'royalblue', alpha = 0.5, label = 'pre')
plt.hist(means_post, color = 'salmon', alpha = 0.5, label = 'post')
plt.legend()
plt.title('Delta center frequency')
plt.show()

# %% [markdown]
# **Wilcoxon Test**

# %%
print(wilcoxon(means_pre, means_post))
# Out:
#           W-val alternative  p-val  RBC  CLES
# Wilcoxon    0.0   two-sided    0.5  1.0  0.75

# %% [markdown]
# **Permutation Test & T-Test**

# %%
perm_test(exp_df_mean, feature='delta_cf')
# Out:
# The probability from the sampling statistics is =  1.0
#
#               T  dof alternative     p-val           CI95%   cohen-d  BF10  \
# T-test  1.37187    1   two-sided  0.400994  [-9.92, 12.32]  0.912208  0.85
#
#            power
# T-test  0.086456

# %% [markdown]
# ### Theta Oscillatory Power: Pre/Post

# %% [markdown]
# **Normality**

# %%
means_pre = exp_df_mean[exp_df_mean['pre_post']=='pre']['theta_amp'].values
means_post = exp_df_mean[exp_df_mean['pre_post']=='post']['theta_amp'].values

# normality test
print(normality(means_pre, method='shapiro'))
print(normality(means_post, method='shapiro'))
# Out:
#           W      pval  normal
# 0  0.842294  0.017484   False
#           W      pval  normal
# 0  0.954074  0.524039    True

# %%
print('pre: ' + str(np.nanmean(means_pre)))
print('post: ' + str(np.nanmean(means_post)))
# Out:
# pre: 0.4165059956582805
# post: 0.6098604339283821

# %% [markdown]
# **Distribution of means pre vs. post**

# %%
plt.hist(means_pre, color = 'royalblue', alpha = 0.5, label = 'pre')
plt.hist(means_post, color = 'salmon', alpha = 0.5, label = 'post')
plt.legend()
plt.title('Theta oscillatory power')
plt.show()

# %% [markdown]
# **Wilcoxon Test**

# %%
print(wilcoxon(means_pre, means_post))
# Out:
#           W-val alternative     p-val  RBC      CLES
# Wilcoxon    0.0   two-sided  0.000244 -1.0  0.177515

# %% [markdown]
# **Permutation Test & T-Test**

# %%
perm_test(exp_df_mean, feature='theta_amp')
# Out:
# The probability from the sampling statistics is =  0.0136
#
#                T  dof alternative     p-val           CI95%   cohen-d  \
# T-test -5.630833   12   two-sided  0.000111  [-0.33, -0.15]  1.146328
#
#            BF10     power
# T-test  264.121  0.965963

# %% [markdown]
# ### Theta Band Power: Pre/Post

# %% [markdown]
# **Normality**

# %%
means_pre = exp_df_mean[exp_df_mean['pre_post']=='pre']['theta_bp'].values
means_post = exp_df_mean[exp_df_mean['pre_post']=='post']['theta_bp'].values

# normality test
print(normality(means_pre, method='shapiro'))
print(normality(means_post, method='shapiro'))
# Out:
#         W      pval  normal
# 0  0.9707  0.705767    True
#          W      pval  normal
# 0  0.98106  0.923391    True

# %%
print('pre: ' + str(means_pre.mean()))
print('post: ' + str(means_post.mean()))
# Out:
# pre: -12.170075945847973
# post: -11.842966284121248

# %% [markdown]
# **Distribution of means pre vs. post**

# %%
plt.hist(means_pre, color = 'royalblue', alpha = 0.5, label = 'pre')
plt.hist(means_post, color = 'salmon', alpha = 0.5, label = 'post')
plt.legend()
plt.title('Theta band power')
plt.show()

# %% [markdown]
# **Wilcoxon Test**

# %%
print(wilcoxon(means_pre, means_post))
# Out:
#           W-val alternative     p-val      RBC      CLES
# Wilcoxon   47.0   two-sided  0.004339 -0.65942  0.331758

# %% [markdown]
# **Permutation Test & T-Test**

# %%
perm_test(exp_df_mean, feature='theta_bp')
# Out:
# The probability from the sampling statistics is =  0.0040999999999999995
#
#                T  dof alternative     p-val           CI95%   cohen-d   BF10  \
# T-test -3.447241   22   two-sided  0.002297  [-0.52, -0.13]  0.634715  17.19
#
#            power
# T-test  0.828647

# %% [markdown]
# ### Theta Center Frequency: Pre/Post

# %% [markdown]
# **Normality**

# %%
means_pre = exp_df_mean[exp_df_mean['pre_post']=='pre']['theta_cf'].values
means_post = exp_df_mean[exp_df_mean['pre_post']=='post']['theta_cf'].values

# normality test
print(normality(means_pre, method='shapiro'))
print(normality(means_post, method='shapiro'))
# Out:
#           W      pval  normal
# 0  0.929306  0.298373    True
#           W      pval  normal
# 0  0.957291  0.581259    True

# %% [markdown]
# **Distribution of means pre vs. post**

# %%
plt.hist(means_pre, color = 'royalblue', alpha = 0.5, label = 'pre')
plt.hist(means_post, color = 'salmon', alpha = 0.5, label = 'post')
plt.legend()
plt.title('Theta center frequency')
plt.show()

# %% [markdown]
# **Wilcoxon Test**

# %%
print(wilcoxon(means_pre, means_post))
# Out:
#           W-val alternative     p-val       RBC      CLES
# Wilcoxon   39.0   two-sided  0.684814 -0.142857  0.461538

# %% [markdown]
# **Permutation Test & T-Test**

# %%
perm_test(exp_df_mean, feature='theta_cf')
# Out:
# The probability from the sampling statistics is =  0.7726
#
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -1.155868   12   two-sided  0.270231  [-0.53, 0.16]  0.284927  0.486
#
#            power
# T-test  0.157329

# %% [markdown]
# ### Alpha Oscillatory Power: Pre/Post

# %% [markdown]
# **Normality**

# %%
means_pre = exp_df_mean[exp_df_mean['pre_post']=='pre']['alpha_amp'].values
means_post = exp_df_mean[exp_df_mean['pre_post']=='post']['alpha_amp'].values

# normality test
print(normality(means_pre, method='shapiro'))
print(normality(means_post, method='shapiro'))
# Out:
#           W      pval  normal
# 0  0.951611  0.315921    True
#           W      pval  normal
# 0  0.980892  0.920779    True

# %%
print('pre: ' + str(means_pre.mean()))
print('post: ' + str(means_post.mean()))
# Out:
# pre: 1.0287776308708394
# post: 1.018602032752356

# %% [markdown]
# **Distribution of means pre vs. post**

# %%
plt.hist(means_pre, color = 'royalblue', alpha = 0.5, label = 'pre')
plt.hist(means_post, color = 'salmon', alpha = 0.5, label = 'post')
plt.legend()
plt.title('Alpha oscillatory power')
plt.show()

# %% [markdown]
# **Wilcoxon Test**

# %%
print(wilcoxon(means_pre, means_post))
# Out:
#           W-val alternative     p-val      RBC      CLES
# Wilcoxon  127.0   two-sided  0.753985  0.07971  0.494329

# %% [markdown]
# **Permutation Test & T-Test**

# %%
perm_test(exp_df_mean, feature='alpha_amp')
# Out:
# The probability from the sampling statistics is =  0.5046
#
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test  0.147082   22   two-sided  0.884407  [-0.13, 0.15]  0.024974  0.221
#
#            power
# T-test  0.051507

# %% [markdown]
# ### Alpha Band Power: Pre/Post

# %% [markdown]
# **Normality**

# %%
means_pre = exp_df_mean[exp_df_mean['pre_post']=='pre']['alpha_bp'].values
means_post = exp_df_mean[exp_df_mean['pre_post']=='post']['alpha_bp'].values

# normality test
print(normality(means_pre, method='shapiro'))
print(normality(means_post, method='shapiro'))
# Out:
#           W      pval  normal
# 0  0.962371  0.512884    True
#           W      pval  normal
# 0  0.969331  0.672985    True

# %%
print('pre: ' + str(means_pre.mean()))
print('post: ' + str(means_post.mean()))
# Out:
# pre: -11.818978013267307
# post: -11.682191333954915

# %% [markdown]
# **Distribution of means pre vs. post**

# %%
plt.hist(means_pre, color = 'royalblue', alpha = 0.5, label = 'pre')
plt.hist(means_post, color = 'salmon', alpha = 0.5, label = 'post')
plt.legend()
plt.title('Alpha band power')
plt.show()

# %% [markdown]
# **Wilcoxon Test**

# %%
print(wilcoxon(means_pre, means_post))
# Out:
#           W-val alternative     p-val       RBC      CLES
# Wilcoxon   83.0   two-sided  0.097988 -0.398551  0.401701

# %% [markdown]
# **Permutation Test + T-Test**

# %%
perm_test(exp_df_mean, feature='alpha_bp')
# Out:
# The probability from the sampling statistics is =  0.0328
#
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -1.902084   22   two-sided  0.070334  [-0.29, 0.01]  0.297156  1.013
#
#            power
# T-test  0.275788

# %% [markdown]
# ### Alpha Center Frequency: Pre/Post

# %% [markdown]
# **Normality**

# %%
means_pre = exp_df_mean[exp_df_mean['pre_post']=='pre']['alpha_cf'].values
means_post = exp_df_mean[exp_df_mean['pre_post']=='post']['alpha_cf'].values

# normality test
print(normality(means_pre, method='shapiro'))
print(normality(means_post, method='shapiro'))
# Out:
#           W      pval  normal
# 0  0.972086  0.738771    True
#           W      pval  normal
# 0  0.973004  0.760391    True

# %% [markdown]
# **Distribution of means pre vs. post**

# %%
plt.hist(means_pre, color = 'royalblue', alpha = 0.5, label = 'pre')
plt.hist(means_post, color = 'salmon', alpha = 0.5, label = 'post')
plt.legend()
plt.title('Alpha center frequency')
plt.show()

# %% [markdown]
# **Wilcoxon Test**

# %%
print(wilcoxon(means_pre, means_post))
# Out:
#           W-val alternative     p-val       RBC      CLES
# Wilcoxon  106.0   two-sided  0.344685  0.231884  0.528355

# %% [markdown]
# **Permutation Test & T-Test**

# %%
perm_test(exp_df_mean, feature='alpha_cf')
# Out:
# The probability from the sampling statistics is =  0.5095999999999999
#
#                T  dof alternative     p-val          CI95%   cohen-d  BF10  \
# T-test  1.057096   22   two-sided  0.301938  [-0.11, 0.34]  0.173946  0.36
#
#            power
# T-test  0.125585

# %% [markdown]
# ## Presence/Absence/Percentage of Channels with Oscillations
#
# We are determining what % of channels have a delta oscillation per participant, per pre/post

# %% [markdown]
# ### Delta Percentage

# %%
# Create a new df to find # of channels per person per pre/post that do not have 'nan' 
# (aka that have a delta oscillation)

features = ['patient','pre_post','channel','delta_cf']
exp_df_delta_osc = exp_df_included[features]
exp_df_delta_osc['delta_present'] = exp_df_delta_osc['delta_cf'].notna()
# Out:
# /var/folders/y7/q610k5y915x9bbdk7w61kb9c0000gn/T/ipykernel_94379/259686611.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df_delta_osc['delta_present'] = exp_df_delta_osc['delta_cf'].notna()

# %%
# With this new df, we want to group by the patient/pre_post to show how many channels have a delta oscillation
# Also need to calculate the total # of channels b/c need to get a percentage 
# (not all pts have same # of channels due to exclusion criteria)

ch_delta = exp_df_delta_osc.groupby(['patient', 'pre_post'])['delta_present'].sum().values
ch_total = exp_df_delta_osc.groupby(['patient', 'pre_post'])['channel'].count().values

ch_delta_perc = ch_delta/ch_total

# %%
# Add the delta oscillation percentages to the other df to determine which value corresponds to pre/post

delta_osc_perc = pd.DataFrame(exp_df_delta_osc.groupby(['patient', 'pre_post'], as_index=False)['delta_present'].sum())
delta_osc_perc['ch_delta_perc'] = ch_delta_perc

# %%
plot_feature_prepost(delta_osc_perc, feature='ch_delta_perc')
plt.ylim(0, 1) # same y axis as ECT
plt.ylabel('delta abundance')
sns.despine()
plt.show()

# %% [markdown]
# **Normality**

# %%
perc_delta_pre = delta_osc_perc[delta_osc_perc['pre_post']=='pre']['ch_delta_perc'].values
perc_delta_post = delta_osc_perc[delta_osc_perc['pre_post']=='post']['ch_delta_perc'].values

# normality test
print(normality(perc_delta_pre, method='shapiro'))
print(normality(perc_delta_post, method='shapiro'))
# Out:
#           W          pval  normal
# 0  0.375688  6.756689e-09   False
#           W      pval  normal
# 0  0.641604  0.000003   False

# %%
print('pre: ' + str(perc_delta_pre.mean()))
print('post: ' + str(perc_delta_post.mean()))
# Out:
# pre: 0.01755233494363929
# post: 0.03425750892669607

# %% [markdown]
# **Wilcoxon Test**

# %%
print(wilcoxon(perc_delta_pre, perc_delta_post))
# Out:
#           W-val alternative     p-val       RBC      CLES
# Wilcoxon    6.5   two-sided  0.065602 -0.711111  0.398866
# /Users/quirine/opt/anaconda3/envs/ECT_Hadas/lib/python3.8/site-packages/scipy/stats/morestats.py:3141: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /Users/quirine/opt/anaconda3/envs/ECT_Hadas/lib/python3.8/site-packages/scipy/stats/morestats.py:3155: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %% [markdown]
# **Permutation Test & T-Test**

# %%
perm_test(delta_osc_perc, feature='ch_delta_perc')
# Out:
# The probability from the sampling statistics is =  2.0
#
#                T  dof alternative     p-val         CI95%   cohen-d  BF10  \
# T-test -2.048983   22   two-sided  0.052576  [-0.03, 0.0]  0.292261  1.27
#
#            power
# T-test  0.268384

# %% [markdown]
# ### Theta Percentage

# %%
# Create a new df to find # of channels per person per pre/post that do not have 'nan' 
# (aka that have a theta oscillation)

features = ['patient','pre_post','channel','theta_cf']
exp_df_theta_osc = exp_df_included[features]
exp_df_theta_osc['theta_present'] = exp_df_theta_osc['theta_cf'].notna()
# Out:
# /var/folders/y7/q610k5y915x9bbdk7w61kb9c0000gn/T/ipykernel_94379/2939216184.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df_theta_osc['theta_present'] = exp_df_theta_osc['theta_cf'].notna()

# %%
# With this new df, we want to group by the patient/pre_post to show how many channels have a theta oscillation
# Also need to calculate the total # of channels b/c need to get a percentage 
# (not all pts have same # of channels due to exclusion criteria)

ch_theta = exp_df_theta_osc.groupby(['patient', 'pre_post'])['theta_present'].sum().values
ch_total = exp_df_theta_osc.groupby(['patient', 'pre_post'])['channel'].count().values

ch_theta_perc = ch_theta/ch_total

# %%
# Add the theta oscillation percentages to the other df to determine which value corresponds to pre/post

theta_osc_perc = pd.DataFrame(exp_df_theta_osc.groupby(['patient', 'pre_post'], as_index=False)['theta_present'].sum())
theta_osc_perc['ch_theta_perc'] = ch_theta_perc

# %%
plot_feature_prepost(theta_osc_perc, feature='ch_theta_perc')
plt.ylabel('theta abundance')
sns.despine()
plt.show()

# %%
perc_theta_pre = theta_osc_perc[theta_osc_perc['pre_post']=='pre']['ch_theta_perc'].values
perc_theta_post = theta_osc_perc[theta_osc_perc['pre_post']=='post']['ch_theta_perc'].values

# %%
print('pre: ' + str(perc_theta_pre.mean()))
print('post: ' + str(perc_theta_post.mean()))
# Out:
# pre: 0.2886056971514243
# post: 0.5195402298850575

# %% [markdown]
# **Wilcoxon Test**

# %%
print(wilcoxon(perc_theta_pre, perc_theta_post))
# Out:
#           W-val alternative     p-val       RBC      CLES
# Wilcoxon   26.5   two-sided  0.010834 -0.690058  0.340265
# /Users/quirine/opt/anaconda3/envs/ECT_Hadas/lib/python3.8/site-packages/scipy/stats/morestats.py:3141: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "

# %% [markdown]
# **Permutation Test & T-Test**

# %%
perm_test(theta_osc_perc, feature='ch_theta_perc')
# Out:
# The probability from the sampling statistics is =  0.0
#
#                T  dof alternative     p-val           CI95%   cohen-d   BF10  \
# T-test -2.733626   22   two-sided  0.012126  [-0.41, -0.06]  0.630395  4.177
#
#            power
# T-test  0.823574

# %% [markdown]
# ### Alpha Percentage

# %%
# Create a new df to find # of channels per person per pre/post that do not have 'nan' 
# (aka that have an alpha oscillation)

features = ['patient','pre_post','channel','alpha_cf']
exp_df_alpha_osc = exp_df_included[features]
exp_df_alpha_osc['alpha_present'] = exp_df_alpha_osc['alpha_cf'].notna()
# Out:
# /var/folders/y7/q610k5y915x9bbdk7w61kb9c0000gn/T/ipykernel_94379/4032763983.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df_alpha_osc['alpha_present'] = exp_df_alpha_osc['alpha_cf'].notna()

# %%
# With this new df, we want to group by the patient/pre_post to show how many channels have an alpha oscillation
# Also need to calculate the total # of channels b/c need to get a percentage 
# (not all pts have same # of channels due to exclusion criteria)

ch_alpha = exp_df_alpha_osc.groupby(['patient', 'pre_post'])['alpha_present'].sum().values
ch_total = exp_df_alpha_osc.groupby(['patient', 'pre_post'])['channel'].count().values

ch_alpha_perc = ch_alpha/ch_total

# %%
# Add the alpha oscillation percentages to the other df to determine which value corresponds to pre/post

alpha_osc_perc = pd.DataFrame(exp_df_alpha_osc.groupby(['patient', 'pre_post'], as_index=False)['alpha_present'].sum())
alpha_osc_perc['ch_alpha_perc'] = ch_alpha_perc

# %%
plot_feature_prepost(alpha_osc_perc, feature='ch_alpha_perc')
plt.ylabel('alpha abundance')
sns.despine()
plt.show()

# %%
perc_alpha_pre = alpha_osc_perc[alpha_osc_perc['pre_post']=='pre']['ch_alpha_perc'].values
perc_alpha_post = alpha_osc_perc[alpha_osc_perc['pre_post']=='post']['ch_alpha_perc'].values

# %%
print('pre: ' + str(perc_alpha_pre.mean()))
print('post: ' + str(perc_alpha_post.mean()))
# Out:
# pre: 0.9940029985007497
# post: 0.9192797540623627

# %% [markdown]
# **Wilcoxon Test**

# %%
print(wilcoxon(perc_alpha_pre, perc_alpha_post))
# Out:
#           W-val alternative     p-val       RBC      CLES
# Wilcoxon    2.0   two-sided  0.093492  0.809524  0.589792
# /Users/quirine/opt/anaconda3/envs/ECT_Hadas/lib/python3.8/site-packages/scipy/stats/morestats.py:3141: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /Users/quirine/opt/anaconda3/envs/ECT_Hadas/lib/python3.8/site-packages/scipy/stats/morestats.py:3155: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %% [markdown]
# **Permutation Test & T-Test**

# %%
perm_test(alpha_osc_perc, feature='ch_alpha_perc')
# Out:
# The probability from the sampling statistics is =  2.0
#
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test  1.892204   22   two-sided  0.071698  [-0.01, 0.16]  0.566024  0.998
#
#            power
# T-test  0.737152

# %% [markdown]
# ## Merge Percentage Oscillation Dataframes

# %%
# merge percentage dfs
perc_df = pd.merge(theta_osc_perc, delta_osc_perc, how='outer', on=['patient', 'pre_post'])
perc_df = pd.merge(perc_df, alpha_osc_perc, how='outer', on=['patient', 'pre_post'])

# %%
# merge perc with main eeg feature df
exp_df_mean_wperc = pd.merge(exp_df_mean, perc_df, how='outer', on=['patient', 'pre_post'])

# %%
exp_df_mean_wperc.head()
# Out:
#    patient pre_post  exponent     offset  delta_amp   delta_bp  theta_amp  \
# 0        9     post  1.208446 -11.341697        NaN -11.732663   0.544362
# 1        9      pre  1.539365 -10.834145        NaN -11.337355   0.412741
# 2       10     post  0.832824 -12.346809   0.801166 -12.557052        NaN
# 3       10      pre  0.933296 -11.994862        NaN -12.295288        NaN
# 4       18     post  1.095385 -11.326242        NaN -11.604142   0.580875
#
#     theta_bp  theta_cf  delta_cf  alpha_amp   alpha_bp  alpha_bw  alpha_cf  \
# 0 -11.774489  5.493916       NaN   0.967066 -11.755286  2.844290  9.356659
# 1 -11.570345  5.401264       NaN   0.949130 -11.492119  4.459564  9.393488
# 2 -12.956087       NaN       1.0   0.346771 -12.937739  1.835276  9.305791
# 3 -12.650113       NaN       NaN   0.444879 -12.543308  3.055167  9.616828
# 4 -12.017990  6.109107       NaN   0.968075 -11.625856  2.025453  8.887620
#
#    theta_present  ch_theta_perc  delta_present  ch_delta_perc  alpha_present  \
# 0             27       0.900000              0       0.000000             30
# 1              7       0.233333              0       0.000000             30
# 2              0       0.000000              3       0.111111             15
# 3              0       0.000000              0       0.000000             27
# 4              1       0.033333              0       0.000000             30
#
#    ch_alpha_perc
# 0       1.000000
# 1       1.000000
# 2       0.555556
# 3       1.000000
# 4       1.000000

# %% [markdown]
# ## Multiple Regression Spectral Analysis
#
# What EEG features may be predictive of other EEG features? Specifically, what might be driving the band power differences pre vs. post?

# %% [markdown]
# ### Using Treatment Difference

# %% [markdown]
# **Take difference of pre - post**

# %%
# Take features of interest + average over all electrodes per patient
features = ['exponent', 'offset', 'delta_amp', 'delta_bp', 'theta_amp', 'theta_bp', 'theta_cf', 'delta_cf',
            'alpha_amp', 'alpha_bp', 'alpha_cf', 'ch_theta_perc', 'ch_delta_perc', 'ch_alpha_perc']


diff_df_mean_wperc = exp_df_mean_wperc.groupby(['patient'], as_index=False)[features].diff().dropna(0, how='all')
diff_df_mean_wperc['patient'] = exp_df_mean_wperc['patient']

diff_df_mean_wperc
# Out:
# /var/folders/y7/q610k5y915x9bbdk7w61kb9c0000gn/T/ipykernel_94379/1529135655.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only
#   diff_df_mean_wperc = exp_df_mean_wperc.groupby(['patient'], as_index=False)[features].diff().dropna(0, how='all')
#     exponent    offset  delta_amp  delta_bp  theta_amp  theta_bp  theta_cf  \
# 1   0.330919  0.507551        NaN  0.395308  -0.131622  0.204144 -0.092652
# 3   0.100472  0.351947        NaN  0.261764        NaN  0.305974       NaN
# 5   0.141801  0.103285        NaN -0.032558  -0.157742  0.191330 -0.799046
# 7  -0.533674 -0.869353        NaN -0.689035        NaN -0.622732       NaN
# 9  -0.074044  0.426238        NaN  0.626974        NaN  0.316067       NaN
# 11 -0.563327 -0.629721        NaN -0.525365  -0.408787 -0.573998  0.160233
# 13 -0.009385  0.029482        NaN -0.018781  -0.475660 -0.142517 -0.593088
# 15 -0.262296 -0.406232        NaN -0.518947        NaN -0.237654       NaN
# 17 -0.040067  0.007620        NaN -0.027102  -0.058700 -0.032547 -0.019322
# 19  0.211193  0.341899  -0.082352  0.158867        NaN  0.349951       NaN
# 21  0.037219  0.002517        NaN  0.013889  -0.223897 -0.248057  0.223216
# 23 -0.565161 -0.972053        NaN -0.856350  -0.541301 -1.085502  0.104365
# 25 -0.617033 -0.685540        NaN -0.620414        NaN -0.870027       NaN
# 27 -0.712784 -0.924651        NaN -0.793379  -0.271513 -0.700042 -1.323074
# 29 -0.194290 -1.197270        NaN -0.944911        NaN -1.192607       NaN
# 31 -0.466786 -1.051550  -0.291606 -1.043584  -0.284264 -0.907580 -0.920373
# 33  0.028021  0.092584        NaN  0.164831        NaN -0.156933       NaN
# 35 -0.035487 -0.145898        NaN -0.123877  -0.127970 -0.361321  0.808587
# 37 -0.156709 -0.182107        NaN -0.156111  -0.235014 -0.220772  0.058673
# 39 -0.157135 -0.210260        NaN -0.209966  -0.044339 -0.111279  0.103944
# 41 -0.479163 -0.642919        NaN -0.385551        NaN -0.832475       NaN
# 43 -0.166979 -0.199610        NaN -0.260368  -0.169329 -0.362953 -0.094431
# 45 -0.234903 -0.143980        NaN  0.008106        NaN -0.231992       NaN
#
#     delta_cf  alpha_amp  alpha_bp  alpha_cf  ch_theta_perc  ch_delta_perc  \
# 1        NaN  -0.017936  0.263167  0.036829      -0.666667       0.000000
# 3        NaN   0.098108  0.394431  0.311037       0.000000      -0.111111
# 5        NaN   0.070262  0.040261 -0.341386       0.233333       0.000000
# 7        NaN  -0.400523 -0.811300  0.834416       0.833333       0.000000
# 9        NaN  -0.836091 -0.275677 -0.766616      -0.066667       0.000000
# 11       NaN   0.132102 -0.021086  0.030725      -0.300000       0.000000
# 13       NaN   0.294879  0.230431 -0.427630      -0.866667      -0.100000
# 15       NaN  -0.144916 -0.251147  0.308410       0.000000       0.000000
# 17       NaN   0.055846  0.085985 -0.051723      -0.400000       0.000000
# 19  2.075301  -0.239245  0.134441 -0.692659       0.000000       0.033333
# 21       NaN  -0.251063 -0.259710 -0.170503      -0.166667       0.000000
# 23       NaN   0.415207 -0.194936  0.185845      -0.733333       0.000000
# 25       NaN   0.744856  0.359953  0.398931      -0.933333      -0.100000
# 27       NaN   0.066592 -0.259221  0.609113      -0.233333      -0.033333
# 29       NaN   0.116981 -1.086510  0.225249       0.000000       0.037037
# 31  0.325373   0.323917 -0.390972 -0.436798      -0.133333      -0.033333
# 33       NaN  -0.011465 -0.064869  0.458773       0.000000      -0.043478
# 35       NaN   0.011277 -0.188031  0.936227      -0.600000       0.000000
# 37       NaN  -0.318331 -0.320164 -0.630028      -0.344828       0.000000
# 39       NaN   0.259479  0.114826  0.355252       0.133333       0.000000
# 41       NaN   0.349668 -0.139230  1.244509      -0.666667       0.000000
# 43       NaN  -0.098230 -0.199297  0.149932       0.033333      -0.033333
# 45       NaN  -0.387337 -0.307438  0.074917      -0.433333       0.000000
#
#     ch_alpha_perc  patient
# 1        0.000000        9
# 3        0.444444       10
# 5        0.000000       18
# 7        0.000000       22
# 9        0.000000       25
# 11       0.000000       33
# 13       0.600000       35
# 15       0.045455       40
# 17       0.000000       46
# 19       0.000000       47
# 21       0.000000       53
# 23       0.000000       66
# 25       0.000000       69
# 27       0.533333       95
# 29       0.000000      117
# 31       0.233333      119
# 33       0.000000      125
# 35       0.000000      126
# 37      -0.137931      130
# 39       0.000000      134
# 41       0.000000      144
# 43       0.000000      160
# 45       0.000000      191

# %%
# multiple linear regression to see where changes in delta & theta come from
model = ols('delta_bp ~ exponent + ch_delta_perc', diff_df_mean_wperc).fit() # not using amp because not enough values
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               delta_bp   R-squared:                       0.655
# Model:                            OLS   Adj. R-squared:                  0.621
# Method:                 Least Squares   F-statistic:                     19.02
# Date:                Thu, 27 Oct 2022   Prob (F-statistic):           2.36e-05
# Time:                        17:22:11   Log-Likelihood:                -1.2869
# No. Observations:                  23   AIC:                             8.574
# Df Residuals:                      20   BIC:                             11.98
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        -0.0284      0.073     -0.392      0.699      -0.180       0.123
# exponent          1.2473      0.203      6.147      0.000       0.824       1.671
# ch_delta_perc    -1.5363      1.502     -1.023      0.319      -4.669       1.596
# ==============================================================================
# Omnibus:                        6.139   Durbin-Watson:                   1.523
# Prob(Omnibus):                  0.046   Jarque-Bera (JB):                5.840
# Skew:                           0.297   Prob(JB):                       0.0539
# Kurtosis:                       5.396   Cond. No.                         26.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model = ols('theta_bp ~ exponent + ch_theta_perc', diff_df_mean_wperc).fit() # not using amp because not enough values
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               theta_bp   R-squared:                       0.657
# Model:                            OLS   Adj. R-squared:                  0.623
# Method:                 Least Squares   F-statistic:                     19.20
# Date:                Thu, 27 Oct 2022   Prob (F-statistic):           2.22e-05
# Time:                        17:22:11   Log-Likelihood:                -1.6953
# No. Observations:                  23   AIC:                             9.391
# Df Residuals:                      20   BIC:                             12.80
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        -0.0557      0.077     -0.725      0.477      -0.216       0.104
# exponent          1.2422      0.207      6.012      0.000       0.811       1.673
# ch_theta_perc     0.1418      0.148      0.961      0.348      -0.166       0.450
# ==============================================================================
# Omnibus:                       17.210   Durbin-Watson:                   1.745
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.959
# Skew:                          -1.471   Prob(JB):                     1.70e-05
# Kurtosis:                       6.776   Cond. No.                         3.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model = ols('alpha_bp ~ exponent + alpha_amp + ch_alpha_perc', diff_df_mean_wperc).fit() # not using amp because not enough values
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               alpha_bp   R-squared:                       0.399
# Model:                            OLS   Adj. R-squared:                  0.305
# Method:                 Least Squares   F-statistic:                     4.213
# Date:                Thu, 27 Oct 2022   Prob (F-statistic):             0.0192
# Time:                        17:22:12   Log-Likelihood:                -1.7757
# No. Observations:                  23   AIC:                             11.55
# Df Residuals:                      19   BIC:                             16.09
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        -0.0435      0.078     -0.561      0.582      -0.206       0.119
# exponent          0.6308      0.226      2.791      0.012       0.158       1.104
# alpha_amp         0.5189      0.203      2.557      0.019       0.094       0.944
# ch_alpha_perc     0.3029      0.335      0.905      0.377      -0.398       1.004
# ==============================================================================
# Omnibus:                       26.762   Durbin-Watson:                   1.595
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.570
# Skew:                          -2.081   Prob(JB):                     3.84e-12
# Kurtosis:                       9.126   Cond. No.                         5.82
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.regplot(diff_df_mean_wperc['theta_amp'], diff_df_mean_wperc['theta_bp'])
# Out:
# /Users/quirine/opt/anaconda3/envs/ECT_Hadas/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='theta_amp', ylabel='theta_bp'>

# %%
sns.regplot(diff_df_mean_wperc['ch_theta_perc'], diff_df_mean_wperc['theta_bp'])
# Out:
# /Users/quirine/opt/anaconda3/envs/ECT_Hadas/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ch_theta_perc', ylabel='theta_bp'>

# %%
sns.regplot(diff_df_mean_wperc['offset'], diff_df_mean_wperc['theta_bp'])
# Out:
# /Users/quirine/opt/anaconda3/envs/ECT_Hadas/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='offset', ylabel='theta_bp'>

# %%
sns.regplot(diff_df_mean_wperc['exponent'], diff_df_mean_wperc['theta_bp'])
# Out:
# /Users/quirine/opt/anaconda3/envs/ECT_Hadas/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='exponent', ylabel='theta_bp'>
